# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Import des datas

# %%
file_path = 'data_qg.xlsx'

sheet_names = [
    'GDP',
    'T10', 'T1', 'SP', 'IP', 'Emply',
    'Exptn', 'Exptn1', 'PI', 'LEI',
    'Manu', 'Manu1', 'Oil'
]


dfs = {
    name: pd.read_excel(file_path, sheet_name=name)
    for name in sheet_names
}

for name, df in dfs.items():
    df['Date'] = pd.to_datetime(df['Date'])
    value_col = df.columns[1]
    df = df.rename(columns={value_col: name})
    df = df.set_index('Date')
    dfs[name] = df[[name]]

data = pd.concat(dfs.values(), axis=1)
data = data.sort_index()
data['TERM'] = data['T10'] - data['T1']
data
# Out:
#             GDP   T10    T1       SP      IP  Emply  Exptn  Exptn1  PI  LEI  \
# Date
# 1919-01-01  NaN   NaN   NaN      NaN  4.8739    NaN    NaN     NaN NaN  NaN
# 1919-02-01  NaN   NaN   NaN      NaN  4.6585    NaN    NaN     NaN NaN  NaN
# 1919-03-01  NaN   NaN   NaN      NaN  4.5238    NaN    NaN     NaN NaN  NaN
# 1919-04-01  NaN   NaN   NaN      NaN  4.6046    NaN    NaN     NaN NaN  NaN
# 1919-05-01  NaN   NaN   NaN      NaN  4.6315    NaN    NaN     NaN NaN  NaN
# ...         ...   ...   ...      ...     ...    ...    ...     ...  ..  ...
# 2026-01-02  NaN  4.19  3.47  6858.47     NaN    NaN    NaN     NaN NaN  NaN
# 2026-01-05  NaN  4.17  3.47  6902.05     NaN    NaN    NaN     NaN NaN  NaN
# 2026-01-06  NaN  4.18  3.48  6944.82     NaN    NaN    NaN     NaN NaN  NaN
# 2026-01-07  NaN   NaN   NaN  6920.93     NaN    NaN    NaN     NaN NaN  NaN
# 2026-01-08  NaN   NaN   NaN  6911.28     NaN    NaN    NaN     NaN NaN  NaN
#
#             Manu  Manu1  Oil  TERM
# Date
# ...

# %%
data['Manu_final'] = data['Manu'].combine_first(data['Manu1'])

data = data.drop(columns=['Manu', 'Manu1'])
data = data.rename(columns={'Manu_final': 'Manu'})
data
# Out:
#             GDP   T10    T1       SP      IP  Emply  Exptn  Exptn1  PI  LEI  \
# Date
# 1919-01-01  NaN   NaN   NaN      NaN  4.8739    NaN    NaN     NaN NaN  NaN
# 1919-02-01  NaN   NaN   NaN      NaN  4.6585    NaN    NaN     NaN NaN  NaN
# 1919-03-01  NaN   NaN   NaN      NaN  4.5238    NaN    NaN     NaN NaN  NaN
# 1919-04-01  NaN   NaN   NaN      NaN  4.6046    NaN    NaN     NaN NaN  NaN
# 1919-05-01  NaN   NaN   NaN      NaN  4.6315    NaN    NaN     NaN NaN  NaN
# ...         ...   ...   ...      ...     ...    ...    ...     ...  ..  ...
# 2026-01-02  NaN  4.19  3.47  6858.47     NaN    NaN    NaN     NaN NaN  NaN
# 2026-01-05  NaN  4.17  3.47  6902.05     NaN    NaN    NaN     NaN NaN  NaN
# 2026-01-06  NaN  4.18  3.48  6944.82     NaN    NaN    NaN     NaN NaN  NaN
# 2026-01-07  NaN   NaN   NaN  6920.93     NaN    NaN    NaN     NaN NaN  NaN
# 2026-01-08  NaN   NaN   NaN  6911.28     NaN    NaN    NaN     NaN NaN  NaN
#
#             Oil  TERM  Manu
# Date
# ...

# %%
data = data[data.index >= '1959-01-01']
data
# Out:
#             GDP   T10    T1       SP       IP    Emply  Exptn  Exptn1      PI  \
# Date
# 1959-01-01  7.9   NaN   NaN      NaN  21.9998  52478.0    NaN     NaN  2426.0
# 1959-01-02  NaN   NaN   NaN    55.44      NaN      NaN    NaN     NaN     NaN
# 1959-01-05  NaN   NaN   NaN    55.66      NaN      NaN    NaN     NaN     NaN
# 1959-01-06  NaN   NaN   NaN    55.59      NaN      NaN    NaN     NaN     NaN
# 1959-01-07  NaN   NaN   NaN    54.89      NaN      NaN    NaN     NaN     NaN
# ...         ...   ...   ...      ...      ...      ...    ...     ...     ...
# 2026-01-02  NaN  4.19  3.47  6858.47      NaN      NaN    NaN     NaN     NaN
# 2026-01-05  NaN  4.17  3.47  6902.05      NaN      NaN    NaN     NaN     NaN
# 2026-01-06  NaN  4.18  3.48  6944.82      NaN      NaN    NaN     NaN     NaN
# 2026-01-07  NaN   NaN   NaN  6920.93      NaN      NaN    NaN     NaN     NaN
# 2026-01-08  NaN   NaN   NaN  6911.28      NaN      NaN    NaN     NaN     NaN
#
# ...

# %%
rates_m = data["TERM"].copy()
rates_m = rates_m.resample('M').mean()
rates_m.index = pd.to_datetime(rates_m.index)
rates_m
# Out:
# /var/folders/01/1bzxktkn2570y7jdfj2khflc0000gn/T/ipykernel_30141/1944646259.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   rates_m = rates_m.resample('M').mean()
# Date
# 1959-01-31         NaN
# 1959-02-28         NaN
# 1959-03-31         NaN
# 1959-04-30         NaN
# 1959-05-31         NaN
#                 ...
# 2025-09-30    0.460000
# 2025-10-31    0.447727
# 2025-11-30    0.438889
# 2025-12-31    0.601364
# 2026-01-31    0.706667
# Freq: ME, Name: TERM, Length: 805, dtype: float64

# %%
monthly_vars = ['SP', 'IP', 'Emply', 'Emply', 'PI', 'LEI', 'Manu', 'Oil']
X_m = data[monthly_vars].copy()
X_m.index = pd.to_datetime(X_m.index)
X_m = X_m.resample('M').last()
X_m
# Out:
# /var/folders/01/1bzxktkn2570y7jdfj2khflc0000gn/T/ipykernel_30141/4146081411.py:4: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   X_m = X_m.resample('M').last()
#                  SP        IP     Emply     Emply       PI       LEI  \
# Date
# 1959-01-31    55.42   21.9998   52478.0   52478.0   2426.0  100.0065
# 1959-02-28    55.41   22.4306   52688.0   52688.0   2434.8  100.3623
# 1959-03-31    55.44   22.7538   53014.0   53014.0   2452.7  100.6661
# 1959-04-30    57.59   23.2384   53321.0   53321.0   2470.0  100.8976
# 1959-05-31    58.68   23.5885   53550.0   53550.0   2486.4  101.0383
# ...             ...       ...       ...       ...      ...       ...
# 2025-09-30  6688.46  101.6729  159593.0  159593.0  16654.3       NaN
# 2025-10-31  6840.20  101.6160  159488.0  159488.0      NaN       NaN
# 2025-11-30  6849.09  101.7935  159552.0  159552.0      NaN       NaN
# ...

# %%
X_m = X_m.join(rates_m[['TERM']], how='inner')
X_m
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 X_m = X_m.join(rates_m[['TERM']], how='inner')
#       2 X_m
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/series.py:1144, in Series.__getitem__(self, key)
#    1141     key = np.asarray(key, dtype=bool)
#    1142     return self._get_rows_with_mask(key)
# -> 1144 return self._get_with(key)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/series.py:1185, in Series._get_with(self, key)
#    1182         return self.iloc[key]
#    1184 # handle the dup indexing case GH#4246
# -> 1185 return self.loc[key]
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
# ...

# %% [markdown]
# ## Data transformation - TABLE 6

# %% [markdown]
# ![Table 6 – Definition of regressors](table6.png)

# %%
def log(x):
    return np.log(x)

def dlog(x):
    return np.log(x).diff()

# %%
levels_var = ['TERM', 'LEI']
log_vars = ['Exptn']
dlog_vars = ['SP', 'IP', 'Emply', 'PI', 'Manu', 'Oil']

for v in log_vars:
    data[v] = log(data[v])

for v in dlog_vars:
    data[v] = dlog(data[v])
    
data
# Out:
# /var/folders/01/1bzxktkn2570y7jdfj2khflc0000gn/T/ipykernel_30141/2340207500.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[v] = log(data[v])
# /var/folders/01/1bzxktkn2570y7jdfj2khflc0000gn/T/ipykernel_30141/2340207500.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[v] = dlog(data[v])
#             GDP   T10    T1        SP  IP  Emply  Exptn  Exptn1  PI       LEI  \
# Date
# 1959-01-01  7.9   NaN   NaN       NaN NaN    NaN    NaN     NaN NaN  100.0065
# ...
