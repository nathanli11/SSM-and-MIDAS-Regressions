# %%
import pandas as pd

gdp = pd.read_csv("gdp_stat_norm.csv")
X   = pd.read_csv("regressors_stat_norm.csv")

# GDP trimestriel
gdp["Date"] = pd.to_datetime(gdp["Date"])
y_q = pd.Series(gdp["GDP"].values, index=gdp["Date"]).to_period("Q")

# Régressseurs mensuels
X["Date"] = pd.to_datetime(X["Date"])
X_m = X.set_index("Date")   # colonnes: SP, IP, Emply, Exptn, PI, LEI, Oil, Manu, TERM

# %%
from midas.runner_table7 import table7_rmse_grid

# %%
rmse_small_TERM = table7_rmse_grid(
    y_q=y_q,
    X=X_m,
    horizons=range(1, 9),
    regressors=["TERM"],
    Kx_LF=6, m=3, j_obs=2,
    train_end0="1978Q4",
    eval_start="1979Q1",
    eval_end="2009Q1",
    warm_start=True,
    maxiter=100,
)
rmse_small_TERM
# Out:
#              rmse_regular  rmse_multiplicative    n
# regressor h
# TERM      1      0.744669             0.736135  121
#           2      0.729332             0.728833  120
#           3      0.800299             0.808310  119
#           4      0.750735             0.750735  118
#           5      0.772001             0.771723  117
#           6      0.816251             0.813401  116
#           7      0.774256             0.715226  115
#           8      0.762909             0.758437  114

# %%
rmse_small_TERM.to_csv("rmse_small_TERM_table7.csv")

# %%
rmse_small_SP = table7_rmse_grid(
    y_q=y_q,
    X=X_m,
    horizons=range(1, 9),
    regressors=["SP"],
    Kx_LF=6, m=3, j_obs=2,
    train_end0="1978Q4",
    eval_start="1979Q1",
    eval_end="2009Q1",
    warm_start=True,
    maxiter=100,
)
rmse_small_SP
# Out:
#              rmse_regular  rmse_multiplicative    n
# regressor h
# SP        1      0.691450             0.691579  121
#           2      0.732502             0.713238  120
#           3      0.764391             0.778450  119
#           4      0.778869             0.761835  118
#           5      0.795352             0.807945  117
#           6      0.813886             0.798034  116
#           7      0.771886             0.756947  115
#           8      0.733249             0.748429  114

# %%
rmse_small_SP.to_csv("rmse_small_SP_table7.csv")

# %%
rmse_small_IP = table7_rmse_grid(
    y_q=y_q,
    X=X_m,
    horizons=range(1, 9),
    regressors=["IP"],
    Kx_LF=6, m=3, j_obs=2,
    train_end0="1978Q4",
    eval_start="1979Q1",
    eval_end="2009Q1",
    warm_start=True,
    maxiter=100,
)
rmse_small_IP
# Out:
#              rmse_regular  rmse_multiplicative    n
# regressor h
# IP        1      0.710089             0.654977  121
#           2      0.746852             0.749150  120
#           3      0.768351             0.777618  119
#           4      0.745527             0.782150  118
#           5      0.795993             0.789167  117
#           6      0.785535             0.752413  116
#           7      0.744458             0.733230  115
#           8      0.731311             0.714779  114

# %%
rmse_small_IP.to_csv("rmse_small_IP_table7.csv")

# %%
rmse_small_Emply = table7_rmse_grid(
    y_q=y_q,
    X=X_m,
    horizons=range(1, 9),
    regressors=["Emply"],
    Kx_LF=6, m=3, j_obs=2,
    train_end0="1978Q4",
    eval_start="1979Q1",
    eval_end="2009Q1",
    warm_start=True,
    maxiter=100,
)
rmse_small_Emply
# Out:
#              rmse_regular  rmse_multiplicative    n
# regressor h
# Emply     1      0.705846             0.712431  121
#           2      0.757235             0.761358  120
#           3      0.793046             0.800492  119
#           4      0.786842             0.795010  118
#           5      0.800557             0.794430  117
#           6      0.782893             0.788885  116
#           7      0.750512             0.749233  115
#           8      0.727765             0.735553  114

# %%
rmse_small_Emply.to_csv("rmse_small_Emply_table7.csv")

# %%
rmse_small_Exptn = table7_rmse_grid(
    y_q=y_q,
    X=X_m,
    horizons=range(1, 9),
    regressors=["Exptn"],
    Kx_LF=6, m=3, j_obs=2,
    train_end0="1978Q4",
    eval_start="1979Q1",
    eval_end="2009Q1",
    warm_start=True,
    maxiter=100,
)
rmse_small_Exptn

# %%
# rmse_small_Exptn.to_csv("rmse_small_Exptn_table7.csv")

# %%
rmse_small_PI = table7_rmse_grid(
    y_q=y_q,
    X=X_m,
    horizons=range(1, 9),
    regressors=["PI"],
    Kx_LF=6, m=3, j_obs=2,
    train_end0="1978Q4",
    eval_start="1979Q1",
    eval_end="2009Q1",
    warm_start=True,
    maxiter=100,
)
rmse_small_PI
# Out:
#              rmse_regular  rmse_multiplicative    n
# regressor h
# PI        1      0.687859             0.696806  121
#           2      0.758280             0.768630  120
#           3      0.803371             0.806043  119
#           4      0.825844             0.800920  118
#           5      0.802831             0.823984  117
#           6      0.796529             0.841986  116
#           7      0.747537             0.778569  115
#           8      0.762738             0.755703  114

# %%
rmse_small_PI.to_csv("rmse_small_PI_table7.csv")

# %%
rmse_small_LEI = table7_rmse_grid(
    y_q=y_q,
    X=X_m,
    horizons=range(1, 9),
    regressors=["LEI"],
    Kx_LF=6, m=3, j_obs=2,
    train_end0="1978Q4",
    eval_start="1979Q1",
    eval_end="2009Q1",
    warm_start=True,
    maxiter=100,
)
rmse_small_LEI
# Out:
#              rmse_regular  rmse_multiplicative    n
# regressor h
# LEI       1      0.635246             0.634855  121
#           2      0.640286             0.637452  120
#           3      0.641444             0.639332  119
#           4      0.631502             0.631497  118
#           5      0.661815             0.637127  117
#           6      0.678108             0.678108  116
#           7      0.669710             0.669710  115
#           8      0.677876             0.677876  114

# %%
rmse_small_LEI.to_csv("rmse_small_LEI_table7.csv")

# %%
rmse_small_Manu = table7_rmse_grid(
    y_q=y_q,
    X=X_m,
    horizons=range(1, 9),
    regressors=["Manu"],
    Kx_LF=6, m=3, j_obs=2,
    train_end0="1978Q4",
    eval_start="1979Q1",
    eval_end="2009Q1",
    warm_start=True,
    maxiter=100,
)
rmse_small_Manu
# Out:
#              rmse_regular  rmse_multiplicative    n
# regressor h
# Manu      1      0.725967             0.746953  121
#           2      0.752186             0.801501  120
#           3      0.808411             0.798001  119
#           4      0.768068             0.802567  118
#           5      0.788011             0.790641  117
#           6      0.807391             0.849361  116
#           7      0.737750             0.791154  115
#           8      0.796556             0.753086  114

# %%
rmse_small_Manu.to_csv("rmse_small_Manu_table7.csv")

# %%
rmse_small_Oil = table7_rmse_grid(
    y_q=y_q,
    X=X_m,
    horizons=range(1, 9),
    regressors=["Oil"],
    Kx_LF=6, m=3, j_obs=2,
    train_end0="1978Q4",
    eval_start="1979Q1",
    eval_end="2009Q1",
    warm_start=True,
    maxiter=100,
)
rmse_small_Oil
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 rmse_small_Oil = table7_rmse_grid(
#       2     y_q=y_q,
#       3     X=X_m,
#       4     horizons=range(1, 9),
#       5     regressors=["Oil"],
#       6     Kx_LF=6, m=3, j_obs=2,
#       7     train_end0="1978Q4",
#       8     eval_start="1979Q1",
#       9     eval_end="2009Q1",
#      10     warm_start=True,
#      11     maxiter=100,
#      12 )
#      13 rmse_small_Oil
#
# File c:\Users\alixg\Documents\GitHub\SSM-and-MIDAS-Regressions\midas\runner_table7.py:102, in table7_rmse_grid(y_q, X, horizons, regressors, **kwargs)
#     100 x_m = X[name].dropna()
#     101 for h in horizons:
# --> 102     rm1, n1 = recursive_rmse(y_q, x_m, h=h, model="regular", **kwargs)
#     103     rm2, n2 = recursive_rmse(y_q, x_m, h=h, model="multiplicative", **kwargs)
#     104     rows.append((name, h, rm1, rm2, n1))
#
# File c:\Users\alixg\Documents\GitHub\SSM-and-MIDAS-Regressions\midas\runner_table7.py:61, in recursive_rmse(y_q, x_m, h, model, Kx_LF, m, j_obs, train_end0, eval_start, eval_end, warm_start, maxiter)
#      59 # expanding window: fit using data available up to origin (y up to origin; x handled by j_obs inside the model)
#      60 if model == "regular":
# ---> 61     fit = M.fit(y_q=y_q[y_q.index <= origin], x_m=x_m, h=h, origin=origin, theta_init=theta_init, maxiter=maxiter) # type: ignore
#      62     yhat = M.predict_one(y_q=y_q, x_m=x_m, origin=origin)
#      63     if warm_start:
#
# File c:\Users\alixg\Documents\GitHub\SSM-and-MIDAS-Regressions\midas\adl_regular.py:55, in ADLRegularMIDAS.fit(self, y_q, x_m, h, origin, theta_init, maxiter)
#      52 def fit(self, y_q: pd.Series, x_m: pd.Series, h: int, origin: pd.Period,
#      53         theta_init: Tuple[float, float] = (0.0, 0.0),
#      54         maxiter: int = 8000) -> MIDASFit:
# ---> 55     Y, ylag, Xlags, _ = self._build_train(y_q, x_m, h=h, origin=origin)
#      57     def obj(theta):
#      58         w = exp_almon_weights(Xlags.shape[1], float(theta[0]), float(theta[1]))
#
# File c:\Users\alixg\Documents\GitHub\SSM-and-MIDAS-Regressions\midas\adl_regular.py:41, in ADLRegularMIDAS._build_train(self, y_q, x_m, h, origin)
#      39     continue
#      40 try:
# ---> 41     xlags = self.idx.stacked_hf_lags(df, t=t, j_obs=self.j_obs, Kx_LF=self.Kx_LF)
#      42 except Exception:
#      43     continue
#
# File c:\Users\alixg\Documents\GitHub\SSM-and-MIDAS-Regressions\midas\midas_base.py:84, in MixedFreqIndexer.stacked_hf_lags(self, df, t, j_obs, Kx_LF)
#      81 """Regular MIDAS stacked lags: length Kx_HF = m*Kx_LF, ordered recent→old."""
#      82 Kx_HF = self.m * int(Kx_LF)
# ---> 84 g = df[df["q"] == t]
#      85 if g.empty:
#      86     raise ValueError(f"No HF data in quarter {t}")
#
# File c:\Users\alixg\anaconda3\Lib\site-packages\pandas\core\ops\common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File c:\Users\alixg\anaconda3\Lib\site-packages\pandas\core\arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File c:\Users\alixg\anaconda3\Lib\site-packages\pandas\core\series.py:6096, in Series._cmp_method(self, other, op)
#    6093 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6095 with np.errstate(all="ignore"):
# -> 6096     res_values = ops.comparison_op(lvalues, rvalues, op)
#    6098 return self._construct_result(res_values, name=res_name)
#
# File c:\Users\alixg\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:279, in comparison_op(left, right, op)
#     270         raise ValueError(
#     271             "Lengths must match to compare", lvalues.shape, rvalues.shape
#     272         )
#     274 if should_extension_dispatch(lvalues, rvalues) or (
#     275     (isinstance(rvalues, (Timedelta, BaseOffset, Timestamp)) or right is NaT)
#     276     and not is_object_dtype(lvalues.dtype)
#     277 ):
#     278     # Call the method on lvalues
# --> 279     res_values = op(lvalues, rvalues)
#     281 elif is_scalar(rvalues) and isna(rvalues):  # TODO: but not pd.NA?
#     282     # numpy does not like comparisons vs None
#     283     if op is operator.ne:
#
# File c:\Users\alixg\anaconda3\Lib\site-packages\pandas\core\ops\common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File c:\Users\alixg\anaconda3\Lib\site-packages\pandas\core\arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File c:\Users\alixg\anaconda3\Lib\site-packages\pandas\core\arrays\datetimelike.py:981, in DatetimeLikeArrayMixin._cmp_method(self, other, op)
#     979 o_mask = isna(other)
#     980 mask = self._isnan | o_mask
# --> 981 if mask.any():
#     982     nat_result = op is operator.ne
#     983     np.putmask(result, mask, nat_result)
#
# File c:\Users\alixg\anaconda3\Lib\site-packages\numpy\core\_methods.py:55, in _any(a, axis, dtype, out, keepdims, where)
#      51 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#      52           initial=_NoValue, where=True):
#      53     return umr_prod(a, axis, dtype, out, keepdims, initial, where)
# ---> 55 def _any(a, axis=None, dtype=None, out=None, keepdims=False, *, where=True):
#      56     # Parsing keyword arguments is currently fairly slow, so avoid it for now
#      57     if where is True:
#      58         return umr_any(a, axis, dtype, out, keepdims)
#
# KeyboardInterrupt:

# %%
rmse_small_Oil.to_csv("rmse_small_Oil_table7.csv")
